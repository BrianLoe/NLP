# %% [markdown]
# # Thread (Meta) reviews sentiment analysis

# %% [markdown]
# Thread is a recent app that was launched by Meta which have similarities with Twitter or X. The app has since gained a lot of users and became the app with most users within the first week of launch. In this notebook I want to analyse the data that is obtained from [Kaggle](https://www.kaggle.com/datasets/shuvammandal121/37000-reviews-of-thread-app-dataset). The reviews were sourced from Google Play Store and Apple App Store. Additionally, the reviews are labeled with rating out of five. The main goal is to develop a model to classify reviews based on sentiment.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from nltk.corpus import words
nltk.download('words')
nltk.download('stopwords')
import string
import contractions
np.random.seed(77)

import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import tensorflow.keras.layers as tfl

from datetime import datetime
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\Brian\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Brian\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
gpu_device = tf.config.list_physical_devices('GPU')[0]
tf.config.experimental.set_memory_growth(gpu_device, True)

# %% [markdown]
# # 1. Data Cleaning

# %%
raw_data = pd.read_csv('37000_reviews_of_thread_app.csv')
raw_data.drop(raw_data.columns[0], axis=1, inplace=True) # remove index column
print('There are {} rows and {} columns'.format(raw_data.shape[0], raw_data.shape[1]))
raw_data.head()
# Out:
# There are 36943 rows and 13 columns
#         source                             review_id  \
# 0  Google Play  7cd90e5b-4829-43b9-9fb4-c8c6d1e339c1
# 1  Google Play  6deb8265-2bac-4524-bcb6-f90829fa4e69
# 2  Google Play  91ef61ce-0f05-4f3b-b3d3-5d19cd408ab8
# 3  Google Play  b7721b78-6b77-4f8c-a1d3-a854af4c1f0f
# 4  Google Play  c89ef522-c94c-4171-878f-1d672dce7f11
#
#                     user_name review_title  \
# 0             Eddie Clark Jr.          NaN
# 1                     Rasa RT          NaN
# 2  SITI NUR HAFIZA BINTI AZIZ          NaN
# 3               Asap Khalifah          NaN
# 4                Syed Hussein          NaN
#
#                                   review_description  rating  thumbs_up  \
# 0                                               Good       5        0.0
# 1                               Weak copy of Twitter       1        0.0
# 2  i wish threads have a save button for images a...       3        0.0
# 3                                            Love it       5        0.0
# 4                                           Very god       5        0.0
#
#            review_date  developer_response  developer_response_date  \
# 0  2023-08-07 19:14:36                 NaN                      NaN
# 1  2023-08-07 19:07:04                 NaN                      NaN
# 2  2023-08-07 18:57:07                 NaN                      NaN
# 3  2023-08-07 18:37:16                 NaN                      NaN
# 4  2023-08-07 18:14:15                 NaN                      NaN
#
#        appVersion laguage_code country_code
# 0  294.0.0.27.110           en           us
# 1             NaN           en           us
# 2  294.0.0.27.110           en           us
# 3             NaN           en           us
# 4             NaN           en           us

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36943 entries, 0 to 36942
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   source                   36943 non-null  object
#  1   review_id                36943 non-null  object
#  2   user_name                36943 non-null  object
#  3   review_title             2000 non-null   object
#  4   review_description       36943 non-null  object
#  5   rating                   36943 non-null  int64
#  6   thumbs_up                34943 non-null  float64
#  7   review_date              36943 non-null  object
#  8   developer_response       0 non-null      float64
#  9   developer_response_date  0 non-null      float64
#  10  appVersion               24855 non-null  object
#  11  laguage_code             36943 non-null  object
#  12  country_code             36943 non-null  object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 3.7+ MB

# %%
raw_data.describe(include='all')
# Out:
#              source                             review_id       user_name  \
# count         36943                                 36943           36943
# unique            2                                 36943           35942
# top     Google Play  7cd90e5b-4829-43b9-9fb4-c8c6d1e339c1  Abhishek Kumar
# freq          34943                                     1              11
# mean            NaN                                   NaN             NaN
# std             NaN                                   NaN             NaN
# min             NaN                                   NaN             NaN
# 25%             NaN                                   NaN             NaN
# 50%             NaN                                   NaN             NaN
# 75%             NaN                                   NaN             NaN
# max             NaN                                   NaN             NaN
#
#        review_title review_description        rating     thumbs_up  \
# count          2000              36943  36943.000000  34943.000000
# unique         1838              30086           NaN           NaN
# top         Threads               Good           NaN           NaN
# freq             15                877           NaN           NaN
# mean            NaN                NaN      3.349376      1.816845
# std             NaN                NaN      1.759170     58.538839
# min             NaN                NaN      1.000000      0.000000
# 25%             NaN                NaN      1.000000      0.000000
# 50%             NaN                NaN      4.000000      0.000000
# 75%             NaN                NaN      5.000000      0.000000
# max             NaN                NaN      5.000000   5557.000000
#
#                 review_date  developer_response  developer_response_date  \
# count                 36943                 0.0                      0.0
# unique                35665                 NaN                      NaN
# top     2023-07-06 23:25:42                 NaN                      NaN
# freq                      4                 NaN                      NaN
# mean                    NaN                 NaN                      NaN
# std                     NaN                 NaN                      NaN
# min                     NaN                 NaN                      NaN
# 25%                     NaN                 NaN                      NaN
# 50%                     NaN                 NaN                      NaN
# 75%                     NaN                 NaN                      NaN
# max                     NaN                 NaN                      NaN
#
#             appVersion laguage_code country_code
# count            24855        36943        36943
# unique               7            1            1
# top     289.0.0.77.109           en           us
# freq             21058        36943        36943
# mean               NaN          NaN          NaN
# std                NaN          NaN          NaN
# min                NaN          NaN          NaN
# 25%                NaN          NaN          NaN
# 50%                NaN          NaN          NaN
# 75%                NaN          NaN          NaN
# max                NaN          NaN          NaN

# %% [markdown]
# From all the reviews sampled, none of them are responded by the developers. The average rating is ~3.35 and for thumbs_up is ~1.8 with maximum value of 5,557. It will be interesting to see what kind of review get these many thumbs up. All reviews are from the country US and typed in english. Some potential duplicate reviews may be located with same user_name, review_title, and review_description.
#
# Update:
# - Discovered that not all reviews are typed in English when splitting the data

# %%
# dropping last 5 columns
raw_data.drop(raw_data.columns[-5:], axis=1, inplace=True)
raw_data.columns
# Out:
# Index(['source', 'review_id', 'user_name', 'review_title',
#        'review_description', 'rating', 'thumbs_up', 'review_date'],
#       dtype='object')

# %%
# changing date to datetime object with format year-month-day
raw_data['review_date'] = pd.to_datetime(raw_data['review_date']).dt.strftime('%Y-%m-%d')
raw_data[['review_date']]
# Out:
#       review_date
# 0      2023-08-07
# 1      2023-08-07
# 2      2023-08-07
# 3      2023-08-07
# 4      2023-08-07
# ...           ...
# 36938  2023-07-06
# 36939  2023-07-06
# 36940  2023-07-05
# 36941  2023-08-06
# 36942  2023-08-01
#
# [36943 rows x 1 columns]

# %%
# Checking duplicates
criteria = {'user_name', 'review_title', 'review_description'}
raw_data.loc[raw_data.duplicated(subset=criteria, keep=False)]
# Out:
#             source                             review_id      user_name  \
# 5955   Google Play  98d56730-539b-480d-b3b0-ea6111db459a  Sandeep Kumar
# 18632  Google Play  9ab5367b-2226-4251-bd37-d5ad91724009    Danish Khan
# 19226  Google Play  b0fe4261-94a7-4ba3-b283-312b9b4377d9   Ashish Singh
# 19486  Google Play  251145a1-f11d-49ea-8eaa-a534aa6359a4    Danish Khan
# 22442  Google Play  aef87b99-894e-4595-8bfc-a7e3dd52eff1   Ashish Singh
# 23687  Google Play  4b9d5340-3692-4848-9585-6eb8d05a72a7  Sandeep Kumar
# 24757  Google Play  98c0487a-70b0-44f2-9f6e-38c9198e1859    Rahul Singh
# 25557  Google Play  180e856e-e27d-416f-9cf7-bd07f95e9a22    Rahul Singh
# 27107  Google Play  49fe6b93-0133-403c-974a-6d36e94c7a26   Rahul Maurya
# 27661  Google Play  3bef46a4-ee07-4db0-a136-f95e791b95e7   Rahul Maurya
#
#       review_title review_description  rating  thumbs_up review_date
# 5955           NaN               Good       5        0.0  2023-07-14
# 18632          NaN               Good       5        0.0  2023-07-07
# 19226          NaN               Good       5        0.0  2023-07-07
# 19486          NaN               Good       5        0.0  2023-07-07
# 22442          NaN               Good       4        0.0  2023-07-07
# 23687          NaN               Good       4        0.0  2023-07-07
# 24757          NaN               Good       5        0.0  2023-07-07
# 25557          NaN               Good       5        0.0  2023-07-07
# 27107          NaN          Very nice       5        0.0  2023-07-06
# 27661          NaN          Very nice       5        0.0  2023-07-06

# %% [markdown]
# Above are potential duplicates in the data. We can see that some reviews have the same criteria but different ratings and review date. We can filter it by different review date so reviews that are made on same day with same criteria are dropped.

# %%
criteria.add('review_date')
raw_data.loc[raw_data.duplicated(subset=criteria, keep=False)]
# Out:
#             source                             review_id     user_name  \
# 18632  Google Play  9ab5367b-2226-4251-bd37-d5ad91724009   Danish Khan
# 19226  Google Play  b0fe4261-94a7-4ba3-b283-312b9b4377d9  Ashish Singh
# 19486  Google Play  251145a1-f11d-49ea-8eaa-a534aa6359a4   Danish Khan
# 22442  Google Play  aef87b99-894e-4595-8bfc-a7e3dd52eff1  Ashish Singh
# 24757  Google Play  98c0487a-70b0-44f2-9f6e-38c9198e1859   Rahul Singh
# 25557  Google Play  180e856e-e27d-416f-9cf7-bd07f95e9a22   Rahul Singh
# 27107  Google Play  49fe6b93-0133-403c-974a-6d36e94c7a26  Rahul Maurya
# 27661  Google Play  3bef46a4-ee07-4db0-a136-f95e791b95e7  Rahul Maurya
#
#       review_title review_description  rating  thumbs_up review_date
# 18632          NaN               Good       5        0.0  2023-07-07
# 19226          NaN               Good       5        0.0  2023-07-07
# 19486          NaN               Good       5        0.0  2023-07-07
# 22442          NaN               Good       4        0.0  2023-07-07
# 24757          NaN               Good       5        0.0  2023-07-07
# 25557          NaN               Good       5        0.0  2023-07-07
# 27107          NaN          Very nice       5        0.0  2023-07-06
# 27661          NaN          Very nice       5        0.0  2023-07-06

# %% [markdown]
# We have in total 4 duplicate reviews here so I am going to drop them.

# %%
raw_data.drop_duplicates(subset=criteria, inplace=True)

# %% [markdown]
# # 2. Exploratory Data Analysis
#
# This will be a short analysis on the non-text data to uncover distribution of ratings, sources, etc.

# %%
plt.figure(figsize=(8,5))
sns.barplot(data = raw_data, x='rating', y='rating', estimator=lambda x: len(x) / len(raw_data) * 100)
plt.ylabel('Count %')
plt.xlabel('Rating')
plt.ylim(0,50)
plt.grid(axis='y', alpha=.5)
plt.title('Ratings count (%)')
plt.show()

# %% [markdown]
# The rating is mainly distributed to 1 and 5 with ~30% and ~47%. Both combined accounted for ~77% of the data. As we are doing binary classification, we can proceed with class 1 and 5 as negative and positve respectively. Otherwise we can include 2 as negative and 4 as positive as well to improve the model. We can do multi-class classification with 3 as neutral but we do not have a lot of samples in the data.
#
# It is common that reviews are misclassified such as one star reviews treated as five star. Usually on Google Play Store and App Store, this entries are errors from reviewers. Unfortunately, identifying them in earlier phase is not possible unless you use pre-trained models to classify the sentiment. However, this defeat the purpose of building a sentiment analysis model. As an alternative, we can do residual/error analysis to observe the misclassified reviews.
#
# One other common thing is typos in reviews as we can see immediately when reading the data (very god == very good). We may need to handle this for improving model's performance.

# %%
plt.figure(figsize=(8,5))
sns.countplot(data = raw_data, x='source')
plt.ylabel('Count')
plt.xlabel('Source')
plt.title('# of reviews from source')
plt.show()

# %% [markdown]
# The reviews are mainly collected from Google Play Store, this might affect on user experience.

# %%
min_r = min(raw_data.review_date)
max_r = max(raw_data.review_date) 
print('The earliest review: {}, The latest review: {}'.format(min_r, max_r))
# Out:
# The earliest review: 2023-07-05, The latest review: 2023-08-07

# %% [markdown]
# Thread was launched on 5th July 2023 which corresponds to the earliest date above. The latest review is recorded in 7th August 2023, so there is one month span of review.

# %% [markdown]
# # 3. Dealing with Text (Preprocessing)

# %% [markdown]
# ## Contractions, Punctuations, Stopwords, Lemmatize
# - Contractions are words that are shorten with punctuations such as can't, don't, won't, etc. So we are going to convert those words.
# - Punctuations do not give meaningful context so we are going to remove them. However it is important that we remove punctuations that are actual punctuations rather than contractions.
# - Stopwords do not give meaningful context to sentiment so we are going to remove them.
# - Lemmatizing stem words into its root but preserve the meaning/context.

# %% [markdown]
# ### Preprocessing Functions

# %%
stop_words = set(stopwords.words('english'))
translator=str.maketrans('','',string.punctuation)

def fix_contractions(review):
    """
    args
    review: string review to remove the contractions from
    return
    string review without contractions.
    """  
    assert isinstance(review,str), "text is not in string type"
    token = contractions.fix(review)
    
    return token

def remove_puncts(review):
    """
    args
    review: string review to remove the punctuations from
    return
    string review without punctuations.
    """  
    assert isinstance(review,str), "text is not in string type"
    token = review.translate(translator)
    
    return token
    
def remove_stopwords(review):
    """
    args
    review: string review to remove the stopwords from
    return
    string review without stopwords and lowercase the words.
    """    
    assert isinstance(review,str), "text is not in string type"
    tokens = word_tokenize(review)
    tokens = [token.lower() for token in tokens if token.lower() not in stop_words]
        
    return ' '.join(tokens)

lemmatizer = WordNetLemmatizer()
def lemmatize(review):
    """
    args
    review: string review to remove the stopwords from
    return
    string review with words lemmatized
    """       
    assert isinstance(review,str), "text is not in string type"
    tokens = word_tokenize(review)
    tokens = [lemmatizer.lemmatize(token.lower()) for token in tokens]
        
    return ' '.join(tokens)

# %%
def preprocess(df):
    """
    preprocess the reviews based on functions above in order.
    args
    df: dataframe for text to be preprocessed
    return
    dataframe with text preprocessed
    """   
    data = df.copy()
    data['preprocess_text'] = data['review_description'].apply(lambda x: fix_contractions(x))
    data['preprocess_text'] = data['preprocess_text'].apply(lambda x: remove_puncts(x))
    data['preprocess_text'] = data['preprocess_text'].apply(lambda x: remove_stopwords(x))
    data['preprocess_text'] = data['preprocess_text'].apply(lambda x: lemmatize(x))
    
    return data

# %%
time = datetime.now()
data_preproc = preprocess(raw_data)
print("Executed in",str(datetime.now() - time)[-12:-7])
data_preproc.head()
# Out:
# Executed in 00:10
#         source                             review_id  \
# 0  Google Play  7cd90e5b-4829-43b9-9fb4-c8c6d1e339c1
# 1  Google Play  6deb8265-2bac-4524-bcb6-f90829fa4e69
# 2  Google Play  91ef61ce-0f05-4f3b-b3d3-5d19cd408ab8
# 3  Google Play  b7721b78-6b77-4f8c-a1d3-a854af4c1f0f
# 4  Google Play  c89ef522-c94c-4171-878f-1d672dce7f11
#
#                     user_name review_title  \
# 0             Eddie Clark Jr.          NaN
# 1                     Rasa RT          NaN
# 2  SITI NUR HAFIZA BINTI AZIZ          NaN
# 3               Asap Khalifah          NaN
# 4                Syed Hussein          NaN
#
#                                   review_description  rating  thumbs_up  \
# 0                                               Good       5        0.0
# 1                               Weak copy of Twitter       1        0.0
# 2  i wish threads have a save button for images a...       3        0.0
# 3                                            Love it       5        0.0
# 4                                           Very god       5        0.0
#
#   review_date                                    preprocess_text
# 0  2023-08-07                                               good
# 1  2023-08-07                                  weak copy twitter
# 2  2023-08-07  wish thread save button image video would like...
# 3  2023-08-07                                               love
# 4  2023-08-07                                                god

# %% [markdown]
# # 4. Dealing with the labels
# We have ratings ranging from 1 to 5 and decided to only keep 1 and 5. We need to convert this to 0 for negative and 1 for positive. So 1 rating is encoded as 0 and 5 rating is encoded as 1. Later on, we can experiment on including 2 and 4 star for either multiclass or including them as negative/positive class.

# %%
model_data = data_preproc.loc[data_preproc.rating.isin([1,5])]
print('There are {} rows and {} columns, {} rows were removed (~{:.2f}% of data)'.format(
    model_data.shape[0], model_data.shape[1], 
    raw_data.shape[0]-model_data.shape[0],
    (raw_data.shape[0]-model_data.shape[0])/raw_data.shape[0]*100
    ))
model_data.head()
# Out:
# There are 28279 rows and 9 columns, 8660 rows were removed (~23.44% of data)
#         source                             review_id        user_name  \
# 0  Google Play  7cd90e5b-4829-43b9-9fb4-c8c6d1e339c1  Eddie Clark Jr.
# 1  Google Play  6deb8265-2bac-4524-bcb6-f90829fa4e69          Rasa RT
# 3  Google Play  b7721b78-6b77-4f8c-a1d3-a854af4c1f0f    Asap Khalifah
# 4  Google Play  c89ef522-c94c-4171-878f-1d672dce7f11     Syed Hussein
# 5  Google Play  950acab8-bc92-4e1e-81c4-3f228ccc7362       Samim Khan
#
#   review_title    review_description  rating  thumbs_up review_date  \
# 0          NaN                  Good       5        0.0  2023-08-07
# 1          NaN  Weak copy of Twitter       1        0.0  2023-08-07
# 3          NaN               Love it       5        0.0  2023-08-07
# 4          NaN              Very god       5        0.0  2023-08-07
# 5          NaN                  Nice       1        0.0  2023-08-07
#
#      preprocess_text
# 0               good
# 1  weak copy twitter
# 3               love
# 4                god
# 5               nice

# %%
model_data.rating = model_data.rating // 5 # this converts 5 into 1 and 1 into 0
model_data.rating
# Out:
# C:\Users\Brian\AppData\Local\Temp\ipykernel_20936\1987144868.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_data.rating = model_data.rating // 5 # this converts 5 into 1 and 1 into 0
# 0        1
# 1        0
# 3        1
# 4        1
# 5        0
#         ..
# 36936    1
# 36937    1
# 36939    1
# 36940    1
# 36941    0
# Name: rating, Length: 28279, dtype: int64

# %% [markdown]
# # 5. Establishing Base Model
# I am planning to do residual analysis on the model to improve the preprocessing stage. At this stage, it might be time-consuming to identify words that are for example, abbreviated, not in english, typos, etc. We can fix this by analysing the error made by the model and continously improve it.

# %% [markdown]
# ## a. Splitting Data
# I am going to split the data by 70% training, 20% validation, and 10% test set. Splitting is done by shuffling randomly on the preprocessed sentences.

# %%
def split_data(df):
    """
    args
    df: dataframe containing preprocessed text and labels to be splitted
    return
    train_sents, train_labels, val_sents, val_labels, test_sents, test_labels: 6 variables for each train, validation, test
    """
    data = df.sample(frac=1, random_state=77)
    train_size = int(len(data) * 0.7)
    val_size = int(len(data) * 0.9)

    sentences = data['preprocess_text'].to_numpy()
    labels = data['rating'].to_numpy()
    
    train_sents = sentences[:train_size]
    val_sents = sentences[train_size:val_size]
    test_sents = sentences[val_size:]
    
    train_labels = labels[:train_size]
    val_labels = labels[train_size:val_size]
    test_labels = labels[val_size:]
    
    return train_sents, train_labels, val_sents, val_labels, test_sents, test_labels

# %%
train_sents, train_labels, val_sents, val_labels, test_sents, test_labels = split_data(model_data)
train_sents
# Out:
# array(['😍👍', 'boring', 'already say thread end better twitter', ...,
#        'hate impose people decide delete account deletes instagram well',
#        'copy product', 'намного лучше чем twitter'], dtype=object)

# %%
train_labels
# Out:
# array([1, 0, 1, ..., 0, 0, 1], dtype=int64)

# %%
length = len(max(train_sents, key=len).split())
print("The maximum length of sentence in training set is", length)
# Out:
# The maximum length of sentence in training set is 122

# %% [markdown]
# We can see from the example of reviews above that some words are not in English, are abbreviated, emojis. We may still discover some variations of this when we establish a base model. At current stage, I am just going to build a simple model with little to no hyperparameter tuning.

# %% [markdown]
# ## b. Preprocessing Inputs
# There are some steps we need to take before training the model with data. First is to preprocess it by tokenizing words and generating paddings.

# %%
OOV_TOKEN = "<OOV>"
NUM_WORDS = 1000
MAX_LEN = 122
EMB_DIM = 16

def tokenize(train_sentences, oov_token=OOV_TOKEN, num_words=NUM_WORDS):
    """
    Tokenize the list of strings ignoring punctuations, emojis
    args
    train_sentences: The sentences from training set
    oov_token: Out of Vocabulary token symbol
    num_words: Number of words to keep when tokenizing
    return
    Tokenizer object containing the word-index dictionary that has been fitted on training sentences
    """
    tokenizer = Tokenizer(oov_token=oov_token, num_words=num_words)
    tokenizer.fit_on_texts(train_sentences)
    return tokenizer

def generate_seq_and_pad(sentences, tokenizer, max_len=MAX_LEN):
    """
    Tokenize the list of strings ignoring punctuations, emojis
    args
    sentences: The sentences to be converted into sequences
    tokenizer: Tokenizer object that has been fitted
    maxlen: Maxmimum length of sentence used for padding
    return
    padded sequences with same length as maxlen
    """   
    sequences = tokenizer.texts_to_sequences(sentences)
    padded_seqs = pad_sequences(sequences, maxlen=max_len)
    
    return padded_seqs

# %%
tokenizer = tokenize(train_sents)
word_index = tokenizer.word_index
print("Vocabulary contains {} words".format(len(word_index)))
# Out:
# Vocabulary contains 15041 words

# %%
train_seq = generate_seq_and_pad(train_sents, tokenizer)
val_seq = generate_seq_and_pad(val_sents, tokenizer)
test_seq = generate_seq_and_pad(test_sents, tokenizer)

print("Padded training sequences have shape:", train_seq.shape)
print("Padded validation sequences have shape:", val_seq.shape)
print("Padded test sequences have shape:", test_seq.shape)
# Out:
# Padded training sequences have shape: (19795, 122)
# Padded validation sequences have shape: (5656, 122)
# Padded test sequences have shape: (2828, 122)

# %% [markdown]
# ## c. Creating Base Model

# %%
def plot_metric(history, metric):
    plt.figure(figsize=(5,3))
    plt.plot(history.history[metric])
    plt.plot(history.history[f'val_{metric}'])
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend([metric, f'val_{metric}'])
    plt.show()

# %%
tf.random.set_seed(77)

# %%
tf.keras.backend.clear_session()

with tf.device('/CPU:0'):
    base_model = tf.keras.models.Sequential([
        tfl.Embedding(NUM_WORDS, EMB_DIM, input_length=MAX_LEN),
        tfl.GlobalAveragePooling1D(),
        tfl.Dense(1, activation='sigmoid')
    ])
    
    EPOCHS = 50
    base_model.compile(loss='binary_crossentropy',
                       optimizer=tf.keras.optimizers.Adam(),
                       metrics=['accuracy']
                      )
    history = base_model.fit(train_seq, train_labels, epochs=EPOCHS, validation_data=(val_seq, val_labels))
# Out:
# Epoch 1/50
# 619/619 [==============================] - 2s 3ms/step - loss: 0.6648 - accuracy: 0.6008 - val_loss: 0.6484 - val_accuracy: 0.6179
# Epoch 2/50
# 619/619 [==============================] - 1s 2ms/step - loss: 0.6343 - accuracy: 0.6300 - val_loss: 0.6080 - val_accuracy: 0.6681
# Epoch 3/50
# 619/619 [==============================] - 2s 2ms/step - loss: 0.5888 - accuracy: 0.6824 - val_loss: 0.5585 - val_accuracy: 0.7143
# Epoch 4/50
# 619/619 [==============================] - 2s 3ms/step - loss: 0.5384 - accuracy: 0.7301 - val_loss: 0.5082 - val_accuracy: 0.7493
# Epoch 5/50
# 619/619 [==============================] - 3s 5ms/step - loss: 0.4908 - accuracy: 0.7755 - val_loss: 0.4640 - val_accuracy: 0.7848
# Epoch 6/50
# 619/619 [==============================] - 2s 3ms/step - loss: 0.4504 - accuracy: 0.8109 - val_loss: 0.4290 - val_accuracy: 0.8285
# Epoch 7/50
# 619/619 [==============================] - 1s 2ms/step - loss: 0.4193 - accuracy: 0.8347 - val_loss: 0.4039 - val_accuracy: 0.8483
# Epoch 8/50
# 619/619 [==============================] - 1s 2ms/step - loss: 0.3957 - accuracy: 0.8468 - val_loss: 0.3846 - val_accuracy: 0.8428
# Epoch 9/50
# 619/619 [==============================] - 1s 2ms/step - loss: 0.3784 - accuracy: 0.8557 - val_loss: 0.3700 - val_accuracy: 0.8554
# Epoch 10/50
# 619/619 [==============================] - 2s 3ms/step - loss: 0.3647 - accuracy: 0.8603 - val_loss: 0.3686 - val_accuracy: 0.8642
# Epoch 11/50
# 619/619 [==============================] - 2s 3ms/step - loss: 0.3546 - accuracy: 0.8637 - val_loss: 0.3526 - val_accuracy: 0.8632
# Epoch 12/50
# 619/619 [==============================] - 2s 3ms/step - loss: 0.3466 - accuracy: 0.8662 - val_loss: 0.3479 - val_accuracy: 0.8612
# Epoch 13/50
# 619/619 [==============================] - 2s 3ms/step - loss: 0.3401 - accuracy: 0.8698 - val_loss: 0.3431 - val_accuracy: 0.8651
# Epoch 14/50
# 619/619 [==============================] - 2s 3ms/step - loss: 0.3349 - accuracy: 0.8702 - val_loss: 0.3398 - val_accuracy: 0.8649
# Epoch 15/50
# 619/619 [==============================] - 3s 5ms/step - loss: 0.3308 - accuracy: 0.8708 - val_loss: 0.3375 - val_accuracy: 0.8655
# Epoch 16/50
# 619/619 [==============================] - 3s 5ms/step - loss: 0.3271 - accuracy: 0.8719 - val_loss: 0.3362 - val_accuracy: 0.8663
# Epoch 17/50
# 619/619 [==============================] - 3s 5ms/step - loss: 0.3244 - accuracy: 0.8728 - val_loss: 0.3415 - val_accuracy: 0.8649
# Epoch 18/50
# 619/619 [==============================] - 3s 5ms/step - loss: 0.3209 - accuracy: 0.8741 - val_loss: 0.3333 - val_accuracy: 0.8649
# Epoch 19/50
# 619/619 [==============================] - 3s 5ms/step - loss: 0.3189 - accuracy: 0.8750 - val_loss: 0.3324 - val_accuracy: 0.8660
# Epoch 20/50
# 619/619 [==============================] - 3s 4ms/step - loss: 0.3172 - accuracy: 0.8745 - val_loss: 0.3322 - val_accuracy: 0.8672
# Epoch 21/50
# 619/619 [==============================] - 3s 4ms/step - loss: 0.3146 - accuracy: 0.8748 - val_loss: 0.3322 - val_accuracy: 0.8639
# Epoch 22/50
# 619/619 [==============================] - 3s 4ms/step - loss: 0.3137 - accuracy: 0.8757 - val_loss: 0.3352 - val_accuracy: 0.8665
# Epoch 23/50
# 619/619 [==============================] - 3s 5ms/step - loss: 0.3115 - accuracy: 0.8768 - val_loss: 0.3315 - val_accuracy: 0.8679
# Epoch 24/50
# 619/619 [==============================] - 3s 4ms/step - loss: 0.3105 - accuracy: 0.8771 - val_loss: 0.3309 - val_accuracy: 0.8642
# Epoch 25/50
# 619/619 [==============================] - 4s 6ms/step - loss: 0.3088 - accuracy: 0.8770 - val_loss: 0.3307 - val_accuracy: 0.8681
# Epoch 26/50
# 619/619 [==============================] - 3s 5ms/step - loss: 0.3078 - accuracy: 0.8783 - val_loss: 0.3307 - val_accuracy: 0.8649
# Epoch 27/50
# 619/619 [==============================] - 3s 4ms/step - loss: 0.3065 - accuracy: 0.8782 - val_loss: 0.3330 - val_accuracy: 0.8692
# Epoch 28/50
# 619/619 [==============================] - 3s 4ms/step - loss: 0.3057 - accuracy: 0.8784 - val_loss: 0.3311 - val_accuracy: 0.8653
# Epoch 29/50
# 619/619 [==============================] - 3s 5ms/step - loss: 0.3046 - accuracy: 0.8785 - val_loss: 0.3337 - val_accuracy: 0.8681
# Epoch 30/50
# 619/619 [==============================] - 3s 5ms/step - loss: 0.3038 - accuracy: 0.8788 - val_loss: 0.3306 - val_accuracy: 0.8663
# Epoch 31/50
# 619/619 [==============================] - 3s 4ms/step - loss: 0.3030 - accuracy: 0.8804 - val_loss: 0.3308 - val_accuracy: 0.8658
# Epoch 32/50
# 619/619 [==============================] - 3s 5ms/step - loss: 0.3023 - accuracy: 0.8802 - val_loss: 0.3360 - val_accuracy: 0.8662
# Epoch 33/50
# 619/619 [==============================] - 3s 4ms/step - loss: 0.3013 - accuracy: 0.8799 - val_loss: 0.3311 - val_accuracy: 0.8667
# Epoch 34/50
# 619/619 [==============================] - 3s 5ms/step - loss: 0.3013 - accuracy: 0.8784 - val_loss: 0.3319 - val_accuracy: 0.8686
# Epoch 35/50
# 619/619 [==============================] - 3s 6ms/step - loss: 0.3001 - accuracy: 0.8795 - val_loss: 0.3317 - val_accuracy: 0.8672
# Epoch 36/50
# 619/619 [==============================] - 3s 5ms/step - loss: 0.3000 - accuracy: 0.8797 - val_loss: 0.3320 - val_accuracy: 0.8665
# Epoch 37/50
# 619/619 [==============================] - 3s 5ms/step - loss: 0.2989 - accuracy: 0.8800 - val_loss: 0.3326 - val_accuracy: 0.8683
# Epoch 38/50
# 619/619 [==============================] - 3s 4ms/step - loss: 0.2989 - accuracy: 0.8804 - val_loss: 0.3338 - val_accuracy: 0.8686
# Epoch 39/50
# 619/619 [==============================] - 3s 5ms/step - loss: 0.2982 - accuracy: 0.8803 - val_loss: 0.3334 - val_accuracy: 0.8676
# Epoch 40/50
# 619/619 [==============================] - 3s 4ms/step - loss: 0.2980 - accuracy: 0.8814 - val_loss: 0.3334 - val_accuracy: 0.8665
# Epoch 41/50
# 619/619 [==============================] - 3s 5ms/step - loss: 0.2974 - accuracy: 0.8815 - val_loss: 0.3341 - val_accuracy: 0.8669
# Epoch 42/50
# 619/619 [==============================] - 3s 5ms/step - loss: 0.2971 - accuracy: 0.8815 - val_loss: 0.3341 - val_accuracy: 0.8674
# Epoch 43/50
# 619/619 [==============================] - 3s 6ms/step - loss: 0.2963 - accuracy: 0.8811 - val_loss: 0.3390 - val_accuracy: 0.8649
# Epoch 44/50
# 619/619 [==============================] - 5s 7ms/step - loss: 0.2965 - accuracy: 0.8809 - val_loss: 0.3373 - val_accuracy: 0.8681
# Epoch 45/50
# 619/619 [==============================] - 4s 7ms/step - loss: 0.2956 - accuracy: 0.8814 - val_loss: 0.3353 - val_accuracy: 0.8656
# Epoch 46/50
# 619/619 [==============================] - 4s 6ms/step - loss: 0.2958 - accuracy: 0.8814 - val_loss: 0.3358 - val_accuracy: 0.8679
# Epoch 47/50
# 619/619 [==============================] - 4s 6ms/step - loss: 0.2956 - accuracy: 0.8825 - val_loss: 0.3357 - val_accuracy: 0.8658
# Epoch 48/50
# 619/619 [==============================] - 4s 6ms/step - loss: 0.2950 - accuracy: 0.8830 - val_loss: 0.3362 - val_accuracy: 0.8656
# Epoch 49/50
# 619/619 [==============================] - 4s 6ms/step - loss: 0.2946 - accuracy: 0.8815 - val_loss: 0.3365 - val_accuracy: 0.8660
# Epoch 50/50
# 619/619 [==============================] - 4s 6ms/step - loss: 0.2946 - accuracy: 0.8822 - val_loss: 0.3368 - val_accuracy: 0.8662

# %%
plot_metric(history, "accuracy")
plot_metric(history, "loss")

# %% [markdown]
# Accuracy on training set and validation set is around ~88% and ~86% respectively.

# %%
test_loss, test_acc = base_model.evaluate(test_seq, test_labels)
print("Loss on test set: {}\nAccuracy on test set: {}".format(test_loss, test_acc))
# Out:
# 89/89 [==============================] - 3s 17ms/step - loss: 0.3408 - accuracy: 0.8667
# Loss on test set: 0.34084147214889526
# Accuracy on test set: 0.8666902184486389

# %% [markdown]
# # 6. Residual Analysis
# For now I am going to analyse the errors made on the training set before going to the validation or test set.

# %%
# reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

# %%
def make_residual_df(model, original_description, sentences, labels, sequences):
    """
    args
    model: the model that is going to used for predicting sequences
    original_description: the original review description from raw data
    sentences: the review description that has been preprocessed (has to be either the train, val, or test set)
    labels: the true labels of sentences (has to be either the train, val, or test set)
    sequences: the input to model that has been preprocessed (has to be either the train, val, or test set)
    
    return - dataframe containing residuals with original and preprocessed review, true label, and predicted label.
    """
    y_hat = (model.predict(sequences)>0.5).astype(int).ravel()
    incorrect_idxs = [i for i in range(len(y_hat)) if y_hat[i]!=labels[i]]
    print("There are {} incorrect predictions".format(len(incorrect_idxs)))

    ori_desc = [original_description[i] for i in incorrect_idxs]
    inc_reviews = [sentences[i] for i in incorrect_idxs]
    true_labels = [labels[i] for i in incorrect_idxs]
    pred_labels = [y_hat[i] for i in incorrect_idxs]

    resid = pd.DataFrame(zip(ori_desc, inc_reviews, true_labels, pred_labels), 
                     columns=['original_review','preproc_review', 'true_label', 'pred_label'])

    return resid

# %%
# original review description
data = model_data.sample(frac=1, random_state=77) # keeping same random state
ori_desc = data['review_description'].to_numpy()

# %%
resid_df = make_residual_df(base_model, ori_desc, train_sents, train_labels, train_seq)
with pd.option_context('display.min_rows', 20):
    display(resid_df.head(20))
# Out:
# 619/619 [==============================] - 5s 9ms/step
# There are 2328 incorrect predictions
#                                       original_review  \
# 0   Not so long ago, there was a great instagram a...
# 1                                           Time vest
# 2                                             Not bad
# 3                                      Zuck is a cuck
# 4   The app is still bugging out i don't know why ...
# 5                         Anything to destroy Twitter
# 6                                                💯🔥🔥💥
# 7   Please make this app exact clone of Twitter th...
# 8        How can you connect with mutuals without dms
# 9                                     No chat no cool
# 10  ,dqqटक य ढठ।ष ्हशज्ज्ज्ञज्ज्ज्ञज्ञज्ञज्ञज्ञज्ञ...
# 11                                             😡😡😡😡😡😡
# 12                                               poop
# 13  Not good tow mistek 1.AV video only no audio 2...
# 14                                                 💩🤢
# 15                                      Why this app?
# 16                                   Interface bugged
# 17                                              کخ کخ
# 18                                                 😂😂
# 19                                    Not good at all
#
#                                        preproc_review  true_label  pred_label
# 0   long ago great instagram app called thread lik...           0           1
# 1                                           time vest           0           1
# 2                                                 bad           1           0
# 3                                           zuck cuck           0           1
# 4                     app still bugging know read bro           0           1
# 5                            anything destroy twitter           1           0
# 6                                                💯🔥🔥💥           0           1
# 7   please make app exact clone twitter convenient...           0           1
# 8                          connect mutuals without dm           0           1
# 9                                           chat cool           0           1
# 10  dqqटक य ढठ।ष ्हशज्ज्ज्ञज्ज्ज्ञज्ञज्ञज्ञज्ञज्ञज...           0           1
# 11                                             😡😡😡😡😡😡           0           1
# 12                                               poop           0           1
# 13  good tow mistek 1av video audio 2language tami...           0           1
# 14                                                 💩🤢           0           1
# 15                                                app           0           1
# 16                                   interface bugged           0           1
# 17                                              کخ کخ           0           1
# 18                                                 😂😂           0           1
# 19                                               good           0           1

# %% [markdown]
# Above are examples of incorrect predictions. Insights from the incorrect predictions:
# -  Emojis may have low samples and may need to be investigated.
# -  Adding stemming words to the preprocessing may be worth investigating.
# -  We can see that `No`, `Not` gives meaningful context in above example so we may add this to custom dictionary.
# -  Twitter seems to be impactful in determining sentiments on this data.
# -  Some reviews lose its context when stopwords are removed.

# %% [markdown]
# ## a. Adding more functions
# Steps:
# - Include `no` and `not` so it is not removed from stopwords.
# - Include reviews that include `+` and `-` followed by a character either before or after such as `A++` or `-5`.
# - For emojis, I am going to see if there are many samples using them.

# %%
# removing 'no' and 'not' from stopwords
stop_words.remove('no')
stop_words.remove('not')

# %%
# add stemming
# ps = PorterStemmer()
# def stem_words(review):
#     """
#     args
#     review: string review to be stemmed
#     return
#     string review after stemming.
#     """  
#     assert isinstance(review,str), "text is not in string type"
#     tokens = word_tokenize(review)
#     tokens = [ps.stem(token) for token in tokens]
    
#     return ' '.join(tokens)

# %%
import re
translator=str.maketrans('','',string.punctuation)

def remove_puncts(review):
    """
    Removes punctuations but keep instances such as '-5', '+10', '5+', 'A+', 'A-'
    args
    review: string review to remove the punctuations from
    return
    string review without punctuations.
    """  
    assert isinstance(review,str), "text is not in string type"
    pattern1 = r"(?i)(10?|[2-9])(?<![^ ]).(?<=[+])(?![^ ])|([A-D]).(?<=[+-])(?![a-z])"
    pattern2 = r"(?i)(?=[+-])(?<![a-z]|[1-9]).(10?|[2-9])(?![a-z])"
    match_str = []
    add_str = ''
    
    try:
        match_str += [s.group() for s in re.finditer(pattern1, review)]
        match_str += [s.group() for s in re.finditer(pattern2, review)]
    except:
        pass
        
    if len(match_str)>0:
        for i in range(len(match_str)):
            review = review.replace(match_str[i], '').strip()
            add_str += match_str[i] + ' '
            
    token = (add_str+review.translate(translator)).strip()
    
    return token

# %% [markdown]
# ## b. Emoji and Non-English Characters

# %%
# add Spacy Emoji NLP object
import spacy
from spacymoji import Emoji
nlp_spacymoji = spacy.load("en_core_web_sm")
nlp_spacymoji.add_pipe('emoji', first=True)

# %%
import emoji
count = 0
for sent in resid_df['original_review'].to_numpy():
    tokens = [token.text for token in nlp_spacymoji(sent)]
    for token in tokens:
        if emoji.is_emoji(token):
            count += 1
            break
print(f'There are {count} reviews that have emojis incorrectly predicted')
# Out:
# There are 467 reviews that have emojis incorrectly predicted

# %% [markdown]
# So there are many reviews with emojis but the model failed to predict them. These emojis may be under-represented in the data, so tuning model may improve it. Alternatively, we could use external dataset to boost the samples.
#
# Next, we are going to remove non-english words from the corpus.

# %%
from nltk.corpus import words
eng_words = words.words()
def check_english_words(review):
    """
    This removes non-english characters except emojis
    args
    review: string review to check for english characters and emojis.
    return
    string review with only english words and emojis.
    """
    assert isinstance(review,str), "text is not in string type"
    # skip checking if all characters are ascii
    try:
        review.encode('ascii')
        return review
    # else check for emojis
    except:
        tokens = [token.text for token in nlp_spacymoji(review)]
        result = []
        for token in tokens:
            if not token.isascii():
                if emoji.is_emoji(token):
                    result.append(token)
                else:
                    word = ''.join([i if ord(i) < 128 else '' for i in token]) # remove non-ascii characters
                    if word in eng_words:
                        result.append(word) # only append if token is in english after removing non-ascii characters
            else:
                result.append(token)
    
        return ' '.join(result)

# %% [markdown]
# Let's rework the preprocess step.

# %%
def preprocess(df):
    """
    preprocess the reviews based on functions above in order.
    args
    df: dataframe for text to be preprocessed
    return
    dataframe with text preprocessed
    """   
    data = df.copy()
    data['preprocess_text'] = data['review_description'].apply(lambda x: fix_contractions(x))
    data['preprocess_text'] = data['preprocess_text'].apply(lambda x: remove_puncts(x))
    data['preprocess_text'] = data['preprocess_text'].apply(lambda x: check_english_words(x))
    data['preprocess_text'] = data['preprocess_text'].apply(lambda x: remove_stopwords(x))
    data['preprocess_text'] = data['preprocess_text'].apply(lambda x: lemmatize(x))
    
    return data

# %%
time = datetime.now()
data_preproc2 = preprocess(model_data)
print("Executed in",str(datetime.now() - time)[-12:-7])
data_preproc2.head()
# Out:
# Executed in 02:12
#         source                             review_id        user_name  \
# 0  Google Play  7cd90e5b-4829-43b9-9fb4-c8c6d1e339c1  Eddie Clark Jr.
# 1  Google Play  6deb8265-2bac-4524-bcb6-f90829fa4e69          Rasa RT
# 3  Google Play  b7721b78-6b77-4f8c-a1d3-a854af4c1f0f    Asap Khalifah
# 4  Google Play  c89ef522-c94c-4171-878f-1d672dce7f11     Syed Hussein
# 5  Google Play  950acab8-bc92-4e1e-81c4-3f228ccc7362       Samim Khan
#
#   review_title    review_description  rating  thumbs_up review_date  \
# 0          NaN                  Good       1        0.0  2023-08-07
# 1          NaN  Weak copy of Twitter       0        0.0  2023-08-07
# 3          NaN               Love it       1        0.0  2023-08-07
# 4          NaN              Very god       1        0.0  2023-08-07
# 5          NaN                  Nice       0        0.0  2023-08-07
#
#      preprocess_text
# 0               good
# 1  weak copy twitter
# 3               love
# 4                god
# 5               nice

# %% [markdown]
# ## c. Handling empty review

# %%
data_preproc2.loc[data_preproc2.preprocess_text=='']
# Out:
#             source                             review_id          user_name  \
# 12     Google Play  2874e126-19f2-4e4e-88da-591be1a8978f      مهووسة ييهيون
# 93     Google Play  61cd38ea-6c34-4886-8def-a6360b8b11dc      Safdar Freedi
# 122    Google Play  b1a5d4f4-97ec-419c-affb-795b083ac997   Facebook Service
# 133    Google Play  0d66ae6d-e887-4e29-8d93-8c5a487e4dad  Alireza Mohammadi
# 157    Google Play  a9ddf0dd-c3b6-464b-83c0-08f4e0258d50         Kumkum Rai
# ...            ...                                   ...                ...
# 34760  Google Play  50d37efb-0b71-47fa-a73a-640e2346dc5a           MOHAMMAD
# 34823  Google Play  7f050114-0302-451f-a645-431e53467609            Mohffyy
# 36299    App Store  d16768ea-bb8c-499c-9f1c-3622704e30f7           haiausue
# 36486    App Store  11886cf2-8b8e-437b-8de1-ea1df1944a9a   Clark Weston Jr.
# 36936    App Store  36ce52a4-4da2-4c3d-a6ca-de068f28645a             yupley
#
#                      review_title  \
# 12                            NaN
# 93                            NaN
# 122                           NaN
# 133                           NaN
# 157                           NaN
# ...                           ...
# 34760                         NaN
# 34823                         NaN
# 36299    I have a good time today
# 36486  Perfect just the way it is
# 36936         Better Than Twitter
#
#                                     review_description  rating  thumbs_up  \
# 12                                               بجربه       1        0.0
# 93                                               کخ کخ       0        0.0
# 122            خمسة نجوم اتمناا ان يكون التطبيق جيدااا       1        0.0
# 133                در هر صورت مثل توییتر گیج کننده است       1        0.0
# 157    स्टाग्राम डाउनलोड नहीं करना ना ता पागल हो जाएगा       1        0.0
# ...                                                ...     ...        ...
# 34760                                             خوبه       1        0.0
# 34823                                         مدري ليه       1        0.0
# 36299                                      He is doing       1        NaN
# 36486                                                .       1        NaN
# 36936                                                …       1        NaN
#
#       review_date preprocess_text
# 12     2023-08-07
# 93     2023-08-06
# 122    2023-08-06
# 133    2023-08-06
# 157    2023-08-06
# ...           ...             ...
# 34760  2023-07-06
# 34823  2023-07-06
# 36299  2023-08-04
# 36486  2023-07-22
# 36936  2023-07-06
#
# [429 rows x 9 columns]

# %% [markdown]
# We are going to remove empty review description due to non-english words. Here, I also found out that the description actually is located in the title. Combining the review title with the review description might help in this case. Also notice that the preprocessed text contain non-meaningful word or even only consist of a character.

# %%
# combining review title and review description
data_aug = model_data.copy()[['review_title', 'review_description', 'rating']]
data_aug.fillna('', inplace=True)
data_aug['comb_desc'] = (data_aug.review_title + ' ' + data_aug.review_description).str.strip()
with pd.option_context('display.min_rows', 20):
    display(data_aug.sample(10, random_state=55))
# Out:
#                                     review_title  \
# 35611  This app has birthed me into a new person
# 24301
# 969
# 22616
# 26389
# 4873
# 9216
# 34721
# 2981
# 16644
#
#                                       review_description  rating  \
# 35611  My skin is clear, my debts are gone, my divorc...       1
# 24301                                    I love Threads.       1
# 969                                He is prafeta App 👍👍👍       0
# 22616                                     It's lagging 🤒       0
# 26389                                           Mike Tel       1
# 4873                    This app is actually really good       1
# 9216   What an app just waste of time no sense of usi...       0
# 34721                                         تطبيق يجنن       1
# 2981                                           Blue tick       1
# 16644              The king is dead, long live the king.       1
#
#                                                comb_desc
# 35611  This app has birthed me into a new person My s...
# 24301                                    I love Threads.
# 969                                He is prafeta App 👍👍👍
# 22616                                     It's lagging 🤒
# 26389                                           Mike Tel
# 4873                    This app is actually really good
# 9216   What an app just waste of time no sense of usi...
# 34721                                         تطبيق يجنن
# 2981                                           Blue tick
# 16644              The king is dead, long live the king.

# %%
with pd.option_context('display.min_rows', 20):
    display(data_aug.loc[(data_aug.review_title!='') & ((data_aug.review_description.str.len())<15)].head(20))
# Out:
#                                review_title review_description  rating  \
# 36299              I have a good time today        He is doing       1
# 36486            Perfect just the way it is                  .       1
# 36609                  Instagram with text…      Works for me!       1
# 36837  Please add a pinned thread option 🙏🏻          See above       1
# 36845                      Elon isn’t in it              10/10       1
# 36905       Anything is better then twitter                Lol       1
# 36933            New social media dropped !           Fire Ong       1
# 36936                   Better Than Twitter                  …       1
# 36940                 Let the battle begin!                😂😂😂       1
#
#                                             comb_desc
# 36299            I have a good time today He is doing
# 36486                    Perfect just the way it is .
# 36609              Instagram with text… Works for me!
# 36837  Please add a pinned thread option 🙏🏻 See above
# 36845                          Elon isn’t in it 10/10
# 36905             Anything is better then twitter Lol
# 36933             New social media dropped ! Fire Ong
# 36936                           Better Than Twitter …
# 36940                       Let the battle begin! 😂😂😂

# %% [markdown]
# Some people made their review on the review title, so the review description may have little to no context. When combined, the review gives more meaning to sentiment, rather than having just punctuations or emojis. We are going to rework the preprocess function for a bit.

# %%
def preprocess(df, column):
    """
    preprocess the reviews based on functions above in order.
    args
    df: dataframe for text to be preprocessed
    column: column name (str) to be preprocessed
    return
    dataframe with text preprocessed
    """   
    data = df.copy()
    data['preprocess_text'] = data[column].apply(lambda x: fix_contractions(x))
    data['preprocess_text'] = data['preprocess_text'].apply(lambda x: remove_puncts(x))
    data['preprocess_text'] = data['preprocess_text'].apply(lambda x: check_english_words(x))
    data['preprocess_text'] = data['preprocess_text'].apply(lambda x: remove_stopwords(x))
    data['preprocess_text'] = data['preprocess_text'].apply(lambda x: lemmatize(x))
    
    return data

# %% [markdown]
# Now we have column as an added parameter to transform the combined review.

# %%
time = datetime.now()
data_preproc3 = preprocess(data_aug, 'comb_desc')
print("Executed in",str(datetime.now() - time)[-12:-7])
data_preproc3.head()
# Out:
# Executed in 00:55
#   review_title    review_description  rating             comb_desc  \
# 0                               Good       1                  Good
# 1               Weak copy of Twitter       0  Weak copy of Twitter
# 3                            Love it       1               Love it
# 4                           Very god       1              Very god
# 5                               Nice       0                  Nice
#
#      preprocess_text
# 0               good
# 1  weak copy twitter
# 3               love
# 4                god
# 5               nice

# %%
with pd.option_context('display.min_rows', 50):
    display(data_preproc3.loc[data_preproc3.preprocess_text==''].tail(50))
# Out:
#       review_title                                 review_description  rating  \
# 31096               حرفيا مارك ابدع برنامج جيد وأفضل من تويتر يحتا...       1
# 31120                                                             ത്ര       0
# 31200                                                        بدون سبب       0
# 31216                      توئیتر در اینستاگرام زاگربرگ در ایلان ماسک       1
# 31231                                                            🅝🅘🅒🅔       1
# 31309                                                         طرش طرش       1
# 31489               एप्लिकेशन बहुत लेग कर रही ह पूरा पेज हिलने लगता ह       0
# 31613                                 لا إلاه إلا الله محمد رسول الله       0
# 31625                          یعنی چی نمیتونیم تو ایران استفاده کنیم       0
# 31710               হ্যালো বন্ধু তোমরা সবাই কেমন আছো ঠিক আছে কি খব...       1
# 32098                                                           عسسسل       1
# 32215                                                বাংলাদেশের কেকে?       1
# 32235                                                        ᵀʰᵉ ᵇᵉˢʳ       1
# 32460                                                            Just       1
# 32675                                                         வணக்கம்       1
# 32764                                       निर्लज्ज, तु फीरसे आ गया?       0
# 32792                                      மிக அருமை! ஆரம்பிக்கலாமா ?       1
# 32831               আমি এটি ব্যাবহার করেছি। চাইলে ব্যাবহার করতে পা...       1
# 32872                                                    What is this       1
# 32999                                        اول تقييم باللغة العربية       1
# 33018                                بسیار عالی زبان فارسی افزود کنید       1
# 33041                                                     نصب نمیشه !       0
# 33081                                                   𝐖𝐨𝐧𝐝𝐞𝐫𝐟𝐮𝐥 𝐚𝐩𝐩       1
# 33086                                               زكارة ف إلون ماسك       1
# 33117                                         حتماً هو أفضل من تويتر!       1
# 33214                                                        جيد جداً       1
# 33303               اولین افغان استم که استفاده میکنم بیبینم چطور است       0
# 33422                                                     بداية موفقة       1
# 33469               Много багов, фризит, окна не обновляются а туп...       0
# 33583                                                   Is what it is       1
# 33751                                  هیوادارم جێگای تویتەر بگرێتەوە       1
# 33784                                                خوب هست بدک نیست       1
# 34154               സാദനം പോളി, സുക്കർബായി നമ്മളെ പണിഎടുക്കാൻ സമ്മ...       1
# 34198                                                              To       1
# 34345                                           الصراحة برنامج أسطوري       1
# 34487                                                          رهيببب       1
# 34519                                                    مرااااا كويس       1
# 34535                                                              :³       1
# 34540                     آب رائع انصحكو لا تنزلونه عشان ميبقاش بصْان       1
# 34547               واقعا مزخرفه حداقل برا منی که توییتری ام یه بر...       0
# 34606                                           قسم بالله التويتر عمه       1
# 34640                                                   احررررق ايلون       1
# 34642                                                           حبييت       1
# 34661                       یعنی متا توی انحصار طلبی داره ترسناک میشه       0
# 34671                       ابلكيشن صح الصح ولا عزاء لمحبين الون ماسك       1
# 34721                                                      تطبيق يجنن       1
# 34729                                                    بحبك يا مارك       1
# 34739                                                           ممتاز       1
# 34760                                                            خوبه       1
# 34823                                                        مدري ليه       1
#
#                                                comb_desc preprocess_text
# 31096  حرفيا مارك ابدع برنامج جيد وأفضل من تويتر يحتا...
# 31120                                                ത്ര
# 31200                                           بدون سبب
# 31216         توئیتر در اینستاگرام زاگربرگ در ایلان ماسک
# 31231                                               🅝🅘🅒🅔
# 31309                                            طرش طرش
# 31489  एप्लिकेशन बहुत लेग कर रही ह पूरा पेज हिलने लगता ह
# 31613                    لا إلاه إلا الله محمد رسول الله
# 31625             یعنی چی نمیتونیم تو ایران استفاده کنیم
# 31710  হ্যালো বন্ধু তোমরা সবাই কেমন আছো ঠিক আছে কি খব...
# 32098                                              عسسسل
# 32215                                   বাংলাদেশের কেকে?
# 32235                                           ᵀʰᵉ ᵇᵉˢʳ
# 32460                                               Just
# 32675                                            வணக்கம்
# 32764                          निर्लज्ज, तु फीरसे आ गया?
# 32792                         மிக அருமை! ஆரம்பிக்கலாமா ?
# 32831  আমি এটি ব্যাবহার করেছি। চাইলে ব্যাবহার করতে পা...
# 32872                                       What is this
# 32999                           اول تقييم باللغة العربية
# 33018                   بسیار عالی زبان فارسی افزود کنید
# 33041                                        نصب نمیشه !
# 33081                                      𝐖𝐨𝐧𝐝𝐞𝐫𝐟𝐮𝐥 𝐚𝐩𝐩
# 33086                                  زكارة ف إلون ماسك
# 33117                            حتماً هو أفضل من تويتر!
# 33214                                           جيد جداً
# 33303  اولین افغان استم که استفاده میکنم بیبینم چطور است
# 33422                                        بداية موفقة
# 33469  Много багов, фризит, окна не обновляются а туп...
# 33583                                      Is what it is
# 33751                     هیوادارم جێگای تویتەر بگرێتەوە
# 33784                                   خوب هست بدک نیست
# 34154  സാദനം പോളി, സുക്കർബായി നമ്മളെ പണിഎടുക്കാൻ സമ്മ...
# 34198                                                 To
# 34345                              الصراحة برنامج أسطوري
# 34487                                             رهيببب
# 34519                                       مرااااا كويس
# 34535                                                 :³
# 34540        آب رائع انصحكو لا تنزلونه عشان ميبقاش بصْان
# 34547  واقعا مزخرفه حداقل برا منی که توییتری ام یه بر...
# 34606                              قسم بالله التويتر عمه
# 34640                                      احررررق ايلون
# 34642                                              حبييت
# 34661          یعنی متا توی انحصار طلبی داره ترسناک میشه
# 34671          ابلكيشن صح الصح ولا عزاء لمحبين الون ماسك
# 34721                                         تطبيق يجنن
# 34729                                       بحبك يا مارك
# 34739                                              ممتاز
# 34760                                               خوبه
# 34823                                           مدري ليه

# %% [markdown]
# Most of the reviews above are written in non-ascii with some combined

# %%
print(len(data_preproc3.loc[data_preproc3.preprocess_text=='']))
# Out:
# 462

# %% [markdown]
# # 7. Back to Model

# %%
train_sents, train_labels, val_sents, val_labels, test_sents, test_labels = split_data(data_preproc3)
train_sents
# Out:
# array(['😍 👍', 'boring', 'already say thread end better twitter', ...,
#        'hate impose people decide delete account deletes instagram well',
#        'copy product', 'twitter'], dtype=object)

# %%
length = len(max(train_sents, key=len).split())
print("The maximum length of sentence in training set is", length)
# Out:
# The maximum length of sentence in training set is 130

# %%
MAX_LEN = 130
tokenizer = tokenize(train_sents)
word_index = tokenizer.word_index
print("Vocabulary contains {} words".format(len(word_index)))
# Out:
# Vocabulary contains 11651 words

# %%
train_seq = generate_seq_and_pad(train_sents, tokenizer, MAX_LEN)
val_seq = generate_seq_and_pad(val_sents, tokenizer, MAX_LEN)
test_seq = generate_seq_and_pad(test_sents, tokenizer, MAX_LEN)

print("Padded training sequences have shape:", train_seq.shape)
print("Padded validation sequences have shape:", val_seq.shape)
print("Padded test sequences have shape:", test_seq.shape)
# Out:
# Padded training sequences have shape: (19795, 130)
# Padded validation sequences have shape: (5656, 130)
# Padded test sequences have shape: (2828, 130)

# %%
tf.keras.backend.clear_session()
from keras import regularizers

with tf.device('/CPU:0'):
    model2 = tf.keras.models.Sequential([
        tfl.Embedding(NUM_WORDS, 20, input_length=MAX_LEN),
        # tfl.SimpleRNN(16, return_sequences=True,),
        tfl.Conv1D(16, 3, activation='relu'),
        tfl.MaxPooling1D(),
        tfl.Dropout(0.2),
        tfl.GlobalMaxPooling1D(),
        tfl.Dense(12, activation='relu', kernel_regularizer=regularizers.L2(1e-7)),
        tfl.Dense(1, activation='sigmoid')
    ])

    early_stop = tf.keras.callbacks.EarlyStopping(
                    monitor='val_loss',
                    min_delta=0,
                    patience=15,
                    verbose=1,
                    mode='min',
                    baseline=.3,
                    restore_best_weights=True,
                )

    lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
                    0.01,
                    decay_steps=50,
                    decay_rate=0.95,
                    staircase=True
                )
    
    EPOCHS = 50
    model2.compile(loss='binary_crossentropy',
                       optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
                       metrics=['accuracy']
                      )
    history = model2.fit(train_seq, train_labels, epochs=EPOCHS, validation_data=(val_seq, val_labels), callbacks=[early_stop])
# Out:
# Epoch 1/50
# 619/619 [==============================] - 4s 5ms/step - loss: 0.3210 - accuracy: 0.8663 - val_loss: 0.2944 - val_accuracy: 0.8881
# Epoch 2/50
# 619/619 [==============================] - 3s 5ms/step - loss: 0.2503 - accuracy: 0.9008 - val_loss: 0.2724 - val_accuracy: 0.8872
# Epoch 3/50
# 619/619 [==============================] - 3s 5ms/step - loss: 0.2248 - accuracy: 0.9119 - val_loss: 0.2724 - val_accuracy: 0.8904
# Epoch 4/50
# 619/619 [==============================] - 3s 5ms/step - loss: 0.2088 - accuracy: 0.9192 - val_loss: 0.2772 - val_accuracy: 0.8904
# Epoch 5/50
# 619/619 [==============================] - 3s 5ms/step - loss: 0.1985 - accuracy: 0.9236 - val_loss: 0.2783 - val_accuracy: 0.8883
# Epoch 6/50
# 619/619 [==============================] - 3s 5ms/step - loss: 0.1926 - accuracy: 0.9265 - val_loss: 0.2818 - val_accuracy: 0.8877
# Epoch 7/50
# 619/619 [==============================] - 3s 5ms/step - loss: 0.1880 - accuracy: 0.9283 - val_loss: 0.2833 - val_accuracy: 0.8884
# Epoch 8/50
# 619/619 [==============================] - 3s 5ms/step - loss: 0.1878 - accuracy: 0.9275 - val_loss: 0.2840 - val_accuracy: 0.8879
# Epoch 9/50
# 619/619 [==============================] - 3s 5ms/step - loss: 0.1871 - accuracy: 0.9291 - val_loss: 0.2843 - val_accuracy: 0.8881
# Epoch 10/50
# 619/619 [==============================] - 3s 5ms/step - loss: 0.1857 - accuracy: 0.9286 - val_loss: 0.2845 - val_accuracy: 0.8879
# Epoch 11/50
# 619/619 [==============================] - 3s 5ms/step - loss: 0.1856 - accuracy: 0.9290 - val_loss: 0.2846 - val_accuracy: 0.8881
# Epoch 12/50
# 619/619 [==============================] - 3s 5ms/step - loss: 0.1866 - accuracy: 0.9282 - val_loss: 0.2846 - val_accuracy: 0.8883
# Epoch 13/50
# 619/619 [==============================] - 3s 5ms/step - loss: 0.1844 - accuracy: 0.9293 - val_loss: 0.2847 - val_accuracy: 0.8881
# Epoch 14/50
# 619/619 [==============================] - 3s 5ms/step - loss: 0.1862 - accuracy: 0.9275 - val_loss: 0.2847 - val_accuracy: 0.8879
# Epoch 15/50
# 619/619 [==============================] - 3s 5ms/step - loss: 0.1844 - accuracy: 0.9304 - val_loss: 0.2847 - val_accuracy: 0.8879
# Epoch 16/50
# 619/619 [==============================] - 3s 5ms/step - loss: 0.1865 - accuracy: 0.9293 - val_loss: 0.2847 - val_accuracy: 0.8879
# Epoch 17/50
# 608/619 [============================>.] - ETA: 0s - loss: 0.1873 - accuracy: 0.9287Restoring model weights from the end of the best epoch: 2.
# 619/619 [==============================] - 3s 5ms/step - loss: 0.1865 - accuracy: 0.9292 - val_loss: 0.2847 - val_accuracy: 0.8879
# Epoch 17: early stopping

# %%
plot_metric(history, "accuracy")
plot_metric(history, "loss")

# %% [markdown]
# When using RNN, the model overfits after ~5 epochs with accuracy stagnant and loss increasing.
#
# After regularization the model successfully prevented the validation loss from increasing, but still the accuracy is not even increasing after 2 epochs on validation set. Now it has ~93% accuracy on training set and ~89% on validation set. Let's further inspect on its error.

# %%
resid_df = make_residual_df(model2, ori_desc, train_sents, train_labels, train_seq)
with pd.option_context('display.min_rows', 20):
    display(resid_df.head(20))
# Out:
# 619/619 [==============================] - 3s 4ms/step
# There are 1608 incorrect predictions
#                                       original_review  \
# 0   Not so long ago, there was a great instagram a...
# 1   فيما كندخل كيخرج مريض اودوي اودي على منافس توي...
# 2                                             Not bad
# 3                                      Zuck is a cuck
# 4                                                💯🔥🔥💥
# 5   ,dqqटक य ढठ।ष ्हशज्ज्ज्ञज्ज्ज्ञज्ञज्ञज्ञज्ञज्ञ...
# 6   This is such a pleasent surprise, couldn't hav...
# 7                                                poop
# 8                                       Why this app?
# 9                                               کخ کخ
# 10                                                 😂😂
# 11                               Keep respect Twitter
# 12                          Instagram but black cover
# 13                                          Thank you
# 14                               Under this agreement
# 15                                              Baaad
# 16                                              Bkwas
# 17  New app are installing but I like Facebook and...
# 18                             Where is Twitter now ?
# 19                    So adorable app Ellon mosk shuk
#
#                                        preproc_review  true_label  pred_label
# 0   not first thread 🙃 not long ago great instagra...           0           1
# 1                                                               0           1
# 2                                             not bad           1           0
# 3                                           zuck cuck           0           1
# 4                                             💯 🔥 🔥 💥           0           1
# 5                                                   z           0           1
# 6   pleasent surprise could not asked juncture wor...           1           0
# 7                                                poop           0           1
# 8                                                 app           0           1
# 9                                                               0           1
# 10                                                😂 😂           0           1
# 11                               keep respect twitter           1           0
# 12                              instagram black cover           0           1
# 13                                              thank           0           1
# 14                                          agreement           0           1
# 15                                              baaad           0           1
# 16                                              bkwas           0           1
# 17      new app installing like facebook insta though           0           1
# 18                                            twitter           1           0
# 19                       adorable app ellon mosk shuk           0           1
